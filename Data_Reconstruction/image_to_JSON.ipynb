# %% [markdown]
# Import required module

# %%
import os

# %% [markdown]
# Meat

# %%
directory = '/Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/'

for filename in os.scandir(directory):
    if filename.is_file():
        
        filename.path
# Out:
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/D21_0043_3_1_2.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/D21_0033_3_4_1.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/S29_0023_3_1_2.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/Z1_0005_3_4_1.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/S29_0053_3_4_1.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/I10_0002_1_2_9.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/N37_N35_0001_1_2_9.png
# /Users/danielbernardo/Desktop/PaPYrus-main fresh/Data Set and Metrics/Thesis Dataset Whole/M4_0001_3_4_1.png
# ...

# %%
import requests
from PIL import Image
import imagehash
import pandas as pd
import ipyplot
import distance                                                    
import numpy                                                                     
import glob
import cv2
import os

# %%
f = r'/Users/danielbernardo/Desktop/CLEAN_DATASET_WHOLE'

# %%
os.listdir(f)
# Out:
# ['D21_0043_3_1_2.png',
#  'D21_0033_3_4_1.png',
#  'S29_0023_3_1_2.png',
#  'Z1_0005_3_4_1.png',
#  'S29_0053_3_4_1.png',
#  'I10_0002_1_2_9.png',
#  'N37_N35_0001_1_2_9.png',
#  'M4_0001_3_4_1.png',
#  'L1_0001_3_4_1.png',
#  'A1_Q3_0001_1_1_4.png',
#  'D36_0007_1_1_4.png',
#  'G1_0003_3_4_1.png',
#  'N23_0021_3_4_1.png',
#  'F4_0003_3_4_1.png',
#  'Z1_Z2_V22_0001_1_1_4.png',
#  'D58_0006_3_4_1.png',
#  'Z7_0015_1_2_9.png',
#  'Z7_0009_3_1_2.png',
#  'D46_0013_3_4_1.png',
#  'A1_0112_3_4_1.png',
#  'S29_0011_1_1_2.png',
#  'N14_0009_3_4_1.png',
#  'D36_X1_0002_3_4_1.png',
#  'A1_0010_2_4_1.png',
#  'X1_0019_1_1_4.png',
#  'X1_D21_0001_1_1_4.png',
#  'M26_0004_1_1_2.png',
#  'Q3_N35_0002_1_4_11.png',
#  'S29_0003_1_4_12.png',
#  'E34_N35_U1_Aa11_D36_0001_3_1_2.png',
#  'W19_0007_3_4_1.png',
#  'N35_0049_1_2_7.png',
#  'G43_0074_3_4_1.png',
#  'A1_0016_1_1_2.png',
#  'G43_0004_3_1_2.png',
#  'G17_0034_1_1_4.png',
#  'D21_N35_S29_0005_3_1_2.png',
#  'M17_0062_3_1_2.png',
# ...

# %% [markdown]
# f = r'/Users/danielbernardo/Desktop/image_hash_full-Dataset'
# for file in os.listdir(f):
#     f_img = f+"/"+file
#     img = Image.open(f_img)
#     img = img.resize((200,200))
#     img.save(f_img)

# %%
df = pd.DataFrame(columns=['Image_Name','ahash','phash','dhash','whash','colorhash'])

for file in os.listdir(f):
    filename = file
    file = f+"/"+file
    file = Image.open(file)
    

    data = {
        'Image_Name': filename,
        'ahash': imagehash.average_hash(file),
        'phash': imagehash.phash(file),
        'dhash': imagehash.dhash(file),
        #'whash': imagehash.whash(file),
        #'colorhash': imagehash.colorhash(file),   
    }
    
    df = df.append(data, ignore_index=True)
# Out:
# /var/folders/z3/w4mm5rz15ldfcx5ccrbqzfh00000gn/T/ipykernel_74602/3192085360.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# /var/folders/z3/w4mm5rz15ldfcx5ccrbqzfh00000gn/T/ipykernel_74602/3192085360.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# /var/folders/z3/w4mm5rz15ldfcx5ccrbqzfh00000gn/T/ipykernel_74602/3192085360.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data, ignore_index=True)
# ...

# %%
whole_hashed_image_dataset = df

# %%
df.head(10)
# Out:
#                Image_Name             ahash             phash  \
# 0      D21_0043_3_1_2.png  e3c3c38000f9fbff  ed34e4cb06cd9a98
# 1      D21_0033_3_4_1.png  fbe3c880043dfdfb  ca65ed8b35c99a30
# 2      S29_0023_3_1_2.png  c383011190f8f8f9  ee26f1d5b8d0a251
# 3       Z1_0005_3_4_1.png  0fc7e1f0f0f0e0e0  eabd339edc038a21
# 4      S29_0053_3_4_1.png  871393c9d998f8f8  e827c73af0f938c0
# 5      I10_0002_1_2_9.png  e0e0f9e3cfbf3f1f  ee604e6534a7bc98
# 6  N37_N35_0001_1_2_9.png  f3e78101fbe080fd  eba5d4c4893b689c
# 7       M4_0001_3_4_1.png  8727e2e0e3e7e7e3  a71e19ba5b50d0e5
# 8       L1_0001_3_4_1.png  f7f1e01383f2c2df  e4cad8d58f1cd530
# 9    A1_Q3_0001_1_1_4.png  cfc9c989fc81817f  fbe9a056963ea190
#
#               dhash whash colorhash
# 0  469e1f21057b0206   NaN       NaN
# 1  228511435cf10b32   NaN       NaN
# 2  066f633731731153   NaN       NaN
# 3  3d0e036523450503   NaN       NaN
# 4  1e66331333313103   NaN       NaN
# 5  0341218619626874   NaN       NaN
# ...

# %%
df.to_csv('image_hashes.csv')

# %%
def find_similar_images(df, phash_column, input_image):
    input = Image.open(input_image)
    phash = str(imagehash.phash(input))
        
    df['hamming_distance'] = df.apply(\
    lambda x: distance.hamming(str(x[phash_column]), phash), axis=1)

    df = df[['Image_Name','phash','hamming_distance']]\
    .sort_values(by='hamming_distance', ascending=True)
    
    return df

# %%
df = find_similar_images(df, 'phash', '/Users/danielbernardo/Desktop/image_hash_full-Dataset/P6_0018_3_4_1.png')

# %%
df.head(10)
# Out:
#                        Image_Name             phash  hamming_distance
# 3872            P6_0018_3_4_1.png  ed33f2e1890919da                 0
# 1094            P6_0021_3_4_1.png  e433f1c1959d19ca                 8
# 9863           V31_0027_3_4_1.png  ea25f2db8904ecd4                 9
# 860             X1_0123_3_4_1.png  ed66b0e589064cdb                 9
# 12055          V31_0006_1_1_6.png  ea35f2fb890c88f0                 9
# 9355            P6_0025_3_4_1.png  ec3bb0d9991918da                 9
# 9796           M40_0001_2_4_1.png  e633d2e496191e1d                 9
# 12971  E34_N35_M17_0001_3_1_2.png  ed36f2e12022d2ed                 9
# 7036           V31_0007_3_4_1.png  eb25f6da810989dc                 9
# 6301            P6_0026_3_4_1.png  e433f8ec840c9de9                 9

# %%
whole_hashed_image_dataset.head(10)
# Out:
#                Image_Name             ahash             phash  \
# 0      D21_0043_3_1_2.png  e3c3c38000f9fbff  ed34e4cb06cd9a98
# 1      D21_0033_3_4_1.png  fbe3c880043dfdfb  ca65ed8b35c99a30
# 2      S29_0023_3_1_2.png  c383011190f8f8f9  ee26f1d5b8d0a251
# 3       Z1_0005_3_4_1.png  0fc7e1f0f0f0e0e0  eabd339edc038a21
# 4      S29_0053_3_4_1.png  871393c9d998f8f8  e827c73af0f938c0
# 5      I10_0002_1_2_9.png  e0e0f9e3cfbf3f1f  ee604e6534a7bc98
# 6  N37_N35_0001_1_2_9.png  f3e78101fbe080fd  eba5d4c4893b689c
# 7       M4_0001_3_4_1.png  8727e2e0e3e7e7e3  a71e19ba5b50d0e5
# 8       L1_0001_3_4_1.png  f7f1e01383f2c2df  e4cad8d58f1cd530
# 9    A1_Q3_0001_1_1_4.png  cfc9c989fc81817f  fbe9a056963ea190
#
#               dhash whash colorhash  hamming_distance
# 0  469e1f21057b0206   NaN       NaN                13
# 1  228511435cf10b32   NaN       NaN                16
# 2  066f633731731153   NaN       NaN                14
# 3  3d0e036523450503   NaN       NaN                15
# ...

# %% [markdown]
# Convert CSV to JSON

# %%
import csv
import json

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['Image_Name']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'/Users/danielbernardo/Desktop/Dissteration Code/Hieratic_Web_App/server/image_hashes.csv'
jsonFilePath = r'/Users/danielbernardo/Desktop/Dissteration Code/Hieratic_Web_App/server/image_hashing_CSV_to_JSON.json'

# %%
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %% [markdown]
# Merger json files by image names
